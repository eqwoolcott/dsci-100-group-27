# %%
heart_read <- read.csv("data/processed.cleveland.data")
heart_read
# Out:
#     X63.0 X1.0 X1.0.1 X145.0 X233.0 X1.0.2 X2.0 X150.0 X0.0 X2.3 X3.0 X0.0.1
# 1   67    1    4      160    286    0      2    108    1    1.5  2    3.0
# 2   67    1    4      120    229    0      2    129    1    2.6  2    2.0
# 3   37    1    3      130    250    0      0    187    0    3.5  3    0.0
# 4   41    0    2      130    204    0      2    172    0    1.4  1    0.0
# 5   56    1    2      120    236    0      0    178    0    0.8  1    0.0
# 6   62    0    4      140    268    0      2    160    0    3.6  3    2.0
# 7   57    0    4      120    354    0      0    163    1    0.6  1    0.0
# 8   63    1    4      130    254    0      2    147    0    1.4  2    1.0
# 9   53    1    4      140    203    1      2    155    1    3.1  3    0.0
# 10  57    1    4      140    192    0      0    148    0    0.4  2    0.0
# 11  56    0    2      140    294    0      2    153    0    1.3  2    0.0
# 12  56    1    3      130    256    1      2    142    1    0.6  2    1.0
# ...

# %%
library(readr)
heart_read_2 <- read_delim("data/cleveland.data",
                          delim = "/t",
                          col_names = FALSE)
heart_read_2
# Out:
# Rows: 2824 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "/t"
# chr (1): X1
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      X1
# 1    1 0 63 1 -9 -9 -9
# 2    -9 1 145 1 233 -9 50 20
# 3    1 -9 1 2 2 3 81 0
# 4    0 0 0 0 1 10.5 6 13
# 5    150 60 190 90 145 85 0 0
# 6    2.3 3 -9 172 0 -9 -9 -9
# 7    -9 -9 -9 6 -9 -9 -9 2
# 8    16 81 0 1 1 1 -9 1
# 9    -9 1 -9 1 1 1 1 1
# 10   1 1 -9 -9 name
# 11   2 0 67 1 -9 -9 -9
# 12   -9 4 160 1 286 -9 40 40
# 13   0 -9 1 2 3 5 81 0
# 14   1 0 0 0 1 9.5 6 13
# 15   108 64 160 90 160 90 1 0
# 16   1.5 2 -9 185 3 -9 -9 -9
# 17   -9 -9 -9 3 -9 -9 -9 2
# 18   5 81 2 1 2 2 -9 2
# 19   -9 1 -9 1 1 1 1 1
# 20   1 1 -9 -9 name
# 21   3 0 67 1 -9 -9 -9
# 22   -9 4 120 1 229 -9 20 35
# 23   0 -9 1 2 2 19 81 0
# 24   1 0 0 0 1 8.5 6 10
# 25   129 78 140 80 120 80 1 0
# ...
